# %% [markdown]
# Hematopoiesis batch effect

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scvelo as scv
import matplotlib.pyplot as plt

import matplotlib as mpl
mpl.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['font.family'] = 'Arial'

# 使用rcParams全局设置隐藏所有边框
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.bottom'] = False
mpl.rcParams['axes.spines.left'] = False

# 可选：如果你也想隐藏刻度线和刻度标签
mpl.rcParams['xtick.bottom'] = False
mpl.rcParams['xtick.labelbottom'] = False
mpl.rcParams['ytick.left'] = False
mpl.rcParams['ytick.labelleft'] = False

# %%
data_dir = 'hsc'
base_dir = '/home/nas3/biod/xueweizhi/velocity_benchmark_output/outputs'
save_dir = f'../figures/{data_dir}'
import os
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
cluster_key = 'cell_type'
batch_key = 'batch'
basis = 'umap_ori'

# %%
batch_list = ['JL_10', 'JL12_0']
model_list = ['scvelo', 'unitvelo', 'velovae', 'deepvelo_cui', 'latentvelo', 'latentvelo_annot', 'velovi', 'stt', 'velovgi']
model_name_list = ['scvelo_dynamical', 'unitvelo', 'velovae', 'deepvelo_cui', 'latentvelo', 'latentvelo', 'velovi', 'stt', 'velovgi']

# %%
import anndata as ad
adata_dict = {}
for model in model_list:
    adata_dict[model] = []
for batch in batch_list:
    for model, model_name in zip(model_list, model_name_list):
        adata_path = f'{base_dir}/{data_dir}/{batch}/{model}/{model_name}.h5ad'
        vkey = f'{model_name}_velocity'
        adata = sc.read_h5ad(adata_path)
        adata_velo = ad.AnnData(X=adata.layers[vkey])
        adata_velo.obs_names = adata.obs_names
        adata_velo.var_names = adata.var_names
        adata_dict[model].append(adata_velo)
adata_concat_dict = {}
for model in model_list:
    adata_concat = ad.concat(adata_dict[model])
    adata_concat_dict[model] = adata_concat
adata_concat_dict
# Out:
# {'scvelo': AnnData object with n_obs × n_vars = 1839 × 2000,
#  'unitvelo': AnnData object with n_obs × n_vars = 1839 × 2000,
#  'velovae': AnnData object with n_obs × n_vars = 1839 × 2000,
#  'deepvelo_cui': AnnData object with n_obs × n_vars = 1839 × 2000,
#  'latentvelo': AnnData object with n_obs × n_vars = 1839 × 2000,
#  'latentvelo_annot': AnnData object with n_obs × n_vars = 1839 × 2000,
#  'velovi': AnnData object with n_obs × n_vars = 1839 × 17,
#  'stt': AnnData object with n_obs × n_vars = 1839 × 2000,
#  'velovgi': AnnData object with n_obs × n_vars = 1839 × 2000}

# %%
data_ref_dir = 'hematopoiesis'
model_ref_list = ['scvelo', 'unitvelo', 'velovae', 'deepvelo_cui', 'latentvelo/batch', 'latentvelo_annot/batch', 'velovi', 'stt', 'velovgi/batch']
data_ref_dict = {}
for model, model_ref_dir, model_name in zip(model_list, model_ref_list, model_name_list):
    adata_path = f'{base_dir}/{data_ref_dir}/{model_ref_dir}/{model_name}.h5ad'
    adata = sc.read_h5ad(adata_path)
    adata_batch = adata_concat_dict[model]
    common_genes = list(set(adata.var_names) & set(adata_batch.var_names))
    adata_batch_aligned = adata_batch[:, common_genes].copy()
    adata_aligned = adata[adata_batch_aligned.obs_names, adata_batch_aligned.var_names].copy()
    adata_aligned.layers['batch_velo'] = adata_batch_aligned.X
    data_ref_dict[model] = adata_aligned
data_ref_dict
# Out:
# {'scvelo': AnnData object with n_obs × n_vars = 1839 × 2000
#      obs: 'batch', 'cell_type', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts', 'velocity_self_transition', 'root_cells', 'end_points', 'velocity_pseudotime', 'latent_time', 'pred_t'
#      var: 'gene_name', 'means', 'dispersions', 'dispersions_norm', 'highly_variable', 'fit_r2', 'fit_alpha', 'fit_beta', 'fit_gamma', 'fit_t_', 'fit_scaling', 'fit_std_u', 'fit_std_s', 'fit_likelihood', 'fit_u0', 'fit_s0', 'fit_pval_steady', 'fit_steady_u', 'fit_steady_s', 'fit_variance', 'fit_alignment_scaling', 'velocity_genes', 'scvelo_dynamical_alpha', 'scvelo_dynamical_beta', 'scvelo_dynamical_gamma'
#      uns: 'neighbors', 'pca', 'recover_dynamics', 'velocity_graph', 'velocity_graph_neg', 'velocity_params'
#      obsm: 'X_pca', 'X_umap', 'X_umap_ori'
#      varm: 'PCs', 'loss'
#      layers: 'Ms', 'Mu', 'X_l_TC', 'X_n_TC', 'ambiguous', 'fit_t', 'fit_tau', 'fit_tau_', 'labeled_TC', 'raw_spliced', 'raw_total', 'raw_unspliced', 'scvelo_dynamical_velocity', 'size_corrected_spliced', 'size_corrected_unspliced', 'sl_TC', 'sn_TC', 'spliced', 'total', 'ul_TC', 'un_TC', 'unlabeled_TC', 'unspliced', 'velocity', 'velocity_u', 'batch_velo'
#      obsp: 'connectivities', 'distances',
#  'unitvelo': AnnData object with n_obs × n_vars = 1839 × 2000
#      obs: 'batch', 'cell_type', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts', 'velocity_self_transition', 'root_cells', 'end_points', 'velocity_pseudotime', 'latent_time', 'pred_t'
#      var: 'gene_name', 'means', 'dispersions', 'dispersions_norm', 'highly_variable', 'velocity_gamma', 'velocity_r2', 'scaling', 'velocity_genes', 'fit_vars', 'fit_varu', 'fit_gamma', 'fit_beta', 'fit_offset', 'fit_a', 'fit_t', 'fit_h', 'fit_intercept', 'fit_loss', 'fit_llf', 'fit_sr2', 'fit_ur2', 'unitvelo_alpha', 'unitvelo_beta', 'unitvelo_gamma'
#      uns: 'base_function', 'basis', 'datapath', 'label', 'loss', 'neighbors', 'par_names', 'pca', 'temp', 'velocity_graph', 'velocity_graph_neg', 'velocity_params'
#      obsm: 'X_pca', 'X_phate', 'X_tsne', 'X_umap', 'X_umap_ori', 'velocity_umap'
#      varm: 'PCs'
#      layers: 'Ms', 'Mu', 'Mu_scale', 'X_l_TC', 'X_n_TC', 'ambiguous', 'fit_t', 'labeled_TC', 'raw_spliced', 'raw_total', 'raw_unspliced', 'size_corrected_spliced', 'size_corrected_unspliced', 'sl_TC', 'sn_TC', 'spliced', 'total', 'ul_TC', 'un_TC', 'unitvelo_s_hat', 'unitvelo_u_hat', 'unitvelo_velocity', 'unlabeled_TC', 'unspliced', 'velocity', 'batch_velo'
#      obsp: 'connectivities', 'distances',
#  'velovae': AnnData object with n_obs × n_vars = 1839 × 2000
#      obs: 'batch', 'cell_type', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts', 'vae_time', 'vae_std_t', 'vae_t0', 'pred_t'
#      var: 'gene_name', 'means', 'dispersions', 'dispersions_norm', 'highly_variable', 'init_mode', 'w_init', 'vae_alpha', 'vae_beta', 'vae_gamma', 'vae_ton', 'vae_scaling', 'vae_sigma_u', 'vae_sigma_s', 'velovae_alpha', 'velovae_beta', 'velovae_gamma'
#      uns: 'neighbors', 'pca', 'vae_run_time', 'vae_test_idx', 'vae_train_idx'
#      obsm: 'X_pca', 'X_phate', 'X_tsne', 'X_umap', 'X_umap_ori', 'vae_std_z', 'vae_z'
#      varm: 'PCs', 'vae_mode'
#      layers: 'Ms', 'Mu', 'X_l_TC', 'X_n_TC', 'ambiguous', 'labeled_TC', 'raw_spliced', 'raw_total', 'raw_unspliced', 'size_corrected_spliced', 'size_corrected_unspliced', 'sl_TC', 'sn_TC', 'spliced', 'total', 'ul_TC', 'un_TC', 'unlabeled_TC', 'unspliced', 'vae_rho', 'vae_s0', 'vae_shat', 'vae_u0', 'vae_uhat', 'vae_velocity', 'vae_velocity_u', 'velovae_velocity', 'batch_velo'
#      obsp: 'connectivities', 'distances',
#  'deepvelo_cui': AnnData object with n_obs × n_vars = 1839 × 2000
#      obs: 'batch', 'cell_type', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts', 'velocity_self_transition', 'root_cells', 'end_points', 'velocity_pseudotime', 'latent_time', 'pred_t'
#      var: 'gene_name', 'means', 'dispersions', 'dispersions_norm', 'highly_variable', 'velocity_gamma', 'velocity_r2', 'velocity_genes', 'deepvelo_cui_alpha', 'deepvelo_cui_beta', 'deepvelo_cui_gamma'
#      uns: 'neighbors', 'pca', 'velocity_graph', 'velocity_graph_neg', 'velocity_params'
#      obsm: 'X_pca', 'X_umap', 'X_umap_ori'
#      varm: 'PCs'
#      layers: 'Ms', 'Mu', 'X_l_TC', 'X_n_TC', 'ambiguous', 'cell_specific_alpha', 'cell_specific_beta', 'cell_specific_gamma', 'deepvelo_cui_s_hat', 'deepvelo_cui_u_hat', 'deepvelo_cui_velocity', 'labeled_TC', 'raw_spliced', 'raw_total', 'raw_unspliced', 'size_corrected_spliced', 'size_corrected_unspliced', 'sl_TC', 'sn_TC', 'spliced', 'total', 'ul_TC', 'un_TC', 'unlabeled_TC', 'unspliced', 'variance_velocity', 'velocity', 'velocity_unspliced', 'batch_velo'
#      obsp: 'connectivities', 'distances',
#  'latentvelo': AnnData object with n_obs × n_vars = 1839 × 2000
#      obs: 'batch', 'cell_type', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts', 'tprior', 'exp_time', 'spliced_size_factor', 'unspliced_size_factor', 'batch_id', 'celltype_id', 'root', 'terminal', 'latent_time', 'pred_t'
#      var: 'gene_name', 'means', 'dispersions', 'dispersions_norm', 'highly_variable', 'velocity_genes', 'R2', 'R2_traj', 'R2_test', 'R2_traj_test'
#      uns: 'index_test', 'neighbors', 'pca', 'scale_spliced', 'scale_unspliced'
#      obsm: 'X_latent', 'X_pca', 'X_phate', 'X_tsne', 'X_umap', 'X_umap_ori', 'batch_onehot', 'latent_velocity'
#      varm: 'PCs'
#      layers: 'Ms', 'Mu', 'X_l_TC', 'X_n_TC', 'ambiguous', 'labeled_TC', 'latentvelo_velocity', 'mask_spliced', 'mask_unspliced', 'raw_spliced', 'raw_total', 'raw_unspliced', 'size_corrected_spliced', 'size_corrected_unspliced', 'sl_TC', 'sn_TC', 'spliced', 'spliced_counts', 'spliced_raw', 'total', 'ul_TC', 'un_TC', 'unlabeled_TC', 'unspliced', 'unspliced_counts', 'unspliced_raw', 'velo', 'velo_s', 'velo_u', 'batch_velo'
#      obsp: 'adj', 'connectivities', 'distances',
#  'latentvelo_annot': AnnData object with n_obs × n_vars = 1839 × 2000
#      obs: 'batch', 'cell_type', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts', 'tprior', 'exp_time', 'spliced_size_factor', 'unspliced_size_factor', 'batch_id', 'celltype', 'celltype_id', 'root', 'terminal', 'latent_time', 'pred_t'
#      var: 'gene_name', 'means', 'dispersions', 'dispersions_norm', 'highly_variable', 'velocity_genes', 'R2', 'R2_traj', 'R2_test', 'R2_traj_test'
#      uns: 'index_test', 'neighbors', 'pca', 'scale_spliced', 'scale_unspliced'
#      obsm: 'X_latent', 'X_pca', 'X_phate', 'X_tsne', 'X_umap', 'X_umap_ori', 'batch_onehot', 'celltype', 'latent_velocity'
#      varm: 'PCs'
#      layers: 'Ms', 'Mu', 'X_l_TC', 'X_n_TC', 'ambiguous', 'labeled_TC', 'latentvelo_velocity', 'mask_spliced', 'mask_unspliced', 'raw_spliced', 'raw_total', 'raw_unspliced', 'size_corrected_spliced', 'size_corrected_unspliced', 'sl_TC', 'sn_TC', 'spliced', 'spliced_counts', 'spliced_raw', 'total', 'ul_TC', 'un_TC', 'unlabeled_TC', 'unspliced', 'unspliced_counts', 'unspliced_raw', 'velo', 'velo_s', 'velo_u', 'batch_velo'
#      obsp: 'adj', 'connectivities', 'distances',
#  'velovi': AnnData object with n_obs × n_vars = 1839 × 14
#      obs: 'batch', 'cell_type', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts', 'pred_t'
#      var: 'gene_name', 'means', 'dispersions', 'dispersions_norm', 'highly_variable', 'velocity_gamma', 'velocity_qreg_ratio', 'velocity_r2', 'velocity_genes', 'fit_alpha', 'fit_beta', 'fit_gamma', 'fit_t_', 'fit_scaling', 'velovi_alpha', 'velovi_beta', 'velovi_gamma'
#      uns: '_scvi_manager_uuid', '_scvi_uuid', 'neighbors', 'pca', 'velocity_params'
#      obsm: 'X_pca', 'X_phate', 'X_tsne', 'X_umap', 'X_umap_ori'
#      varm: 'PCs'
#      layers: 'Ms', 'Mu', 'X_l_TC', 'X_n_TC', 'ambiguous', 'fit_t', 'labeled_TC', 'latent_time_velovi', 'raw_spliced', 'raw_total', 'raw_unspliced', 'size_corrected_spliced', 'size_corrected_unspliced', 'sl_TC', 'sn_TC', 'spliced', 'total', 'ul_TC', 'un_TC', 'unlabeled_TC', 'unspliced', 'velocity', 'velovi_s_hat', 'velovi_u_hat', 'velovi_velocity', 'batch_velo'
#      obsp: 'connectivities', 'distances',
#  'stt': AnnData object with n_obs × n_vars = 1839 × 2000
#      obs: 'batch', 'cell_type', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts', 'attractor', 'entropy', 'speed'
#      var: 'gene_name', 'means', 'dispersions', 'dispersions_norm', 'highly_variable', 'r2_train', 'r2_test'
#      uns: 'da_out', 'gene_subset', 'neighbors', 'par', 'pca', 'r2_keep_test', 'r2_keep_train'
#      obsm: 'X_pca', 'X_umap', 'X_umap_ori', 'rho', 'tensor_v', 'tensor_v_aver'
#      varm: 'PCs'
#      layers: 'Ms', 'Mu', 'X_l_TC', 'X_n_TC', 'ambiguous', 'labeled_TC', 'raw_spliced', 'raw_total', 'raw_unspliced', 'size_corrected_spliced', 'size_corrected_unspliced', 'sl_TC', 'sn_TC', 'spliced', 'stt_velocity', 'total', 'ul_TC', 'un_TC', 'unlabeled_TC', 'unspliced', 'velo', 'batch_velo'
#      obsp: 'connectivities', 'distances',
#  'velovgi': AnnData object with n_obs × n_vars = 1839 × 2000
#      obs: 'batch', 'cell_type', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts'
#      var: 'gene_name', 'means', 'dispersions', 'dispersions_norm', 'highly_variable', 'fit_alpha', 'fit_beta', 'fit_gamma', 'fit_t_', 'fit_scaling'
#      uns: '_scvi_manager_uuid', '_scvi_uuid', 'neighbors', 'pca'
#      obsm: 'X_pca', 'X_phate', 'X_tsne', 'X_umap', 'X_umap_ori'
#      varm: 'PCs'
#      layers: 'Ms', 'Mu', 'X_l_TC', 'X_n_TC', 'ambiguous', 'fit_t', 'labeled_TC', 'latent_time_velovgi', 'raw_spliced', 'raw_total', 'raw_unspliced', 'size_corrected_spliced', 'size_corrected_unspliced', 'sl_TC', 'sn_TC', 'spliced', 'total', 'ul_TC', 'un_TC', 'unlabeled_TC', 'unspliced', 'velocity', 'velocity_u', 'velovgi_velocity', 'batch_velo'
#      obsp: 'connectivities', 'distances'}

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
n_rows = 2
n_cols = 5
fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 5, n_rows * 5))

for i, (model, adata) in enumerate(data_ref_dict.items()):
    vkey = f'{model_name_list[i]}_velocity'
    non_nan_cols = ~np.isnan(adata.layers['batch_velo']).any(axis=0) & ~np.isnan(adata.layers[vkey]).any(axis=0)
    adata = adata[:, non_nan_cols].copy()
    print(model, adata.n_vars)
    adata.obs['batch_sim'] = cosine_similarity(adata.layers['batch_velo'], adata.layers[vkey]).diagonal()
    scv.pl.scatter(adata, basis=basis, color='batch_sim', title=model, color_map='plasma', vmin=-1, vmax=1, ax=axes[i // n_cols, i % n_cols], show=False, colorbar=False)
plt.tight_layout()
plt.savefig(f'{save_dir}/batch_velocity_correlation.svg', bbox_inches='tight')
plt.show()
# Out:
# scvelo 108
# unitvelo 1996
# velovae 2000
# deepvelo_cui 2000
# latentvelo 2000
# latentvelo_annot 2000
# velovi 14
# stt 2000
# velovgi 2000

# %%
adata = data_ref_dict['scvelo']
vkey = 'scvelo_dynamical_velocity'
non_nan_cols = ~np.isnan(adata.layers['batch_velo']).any(axis=0) & ~np.isnan(adata.layers[vkey]).any(axis=0)
sum(non_nan_cols)
# Out:
# 108

# %%
model_ref_dir = 'velovi'
model_name = 'velovi'
model = 'velovi'
adata_path = f'{base_dir}/{data_ref_dir}/{model_ref_dir}/{model_name}.h5ad'
adata = sc.read_h5ad(adata_path)
adata
common_genes = list(set(adata.var_names) & set(adata_concat_dict[model].var_names))
len(common_genes)
# Out:
# 14
