# %% [markdown]
# Dyngen batch effect

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scvelo as scv
import matplotlib.pyplot as plt

import matplotlib as mpl
mpl.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['font.family'] = 'Arial'

# 使用rcParams全局设置隐藏所有边框
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.bottom'] = False
mpl.rcParams['axes.spines.left'] = False

# 可选：如果你也想隐藏刻度线和刻度标签
mpl.rcParams['xtick.bottom'] = False
mpl.rcParams['xtick.labelbottom'] = False
mpl.rcParams['ytick.left'] = False
mpl.rcParams['ytick.labelleft'] = False

# %%
data_dir = 'dyngen'
base_dir = '/home/nas3/biod/xueweizhi/velocity_benchmark_output/outputs'
save_dir = f'../figures/dyngen/batch'
import os
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
cluster_key = 'progress'
batch_key = 'model'
basis = 'umap'

# %%
batch_list = ['batch-left', 'batch-right']
model_list = ['scvelo', 'unitvelo', 'velovae', 'deepvelo_cui', 'latentvelo', 'velovi', 'stt', 'velovgi']
model_name_list = ['scvelo_dynamical', 'unitvelo', 'velovae', 'deepvelo_cui', 'latentvelo', 'velovi', 'stt', 'velovgi']

# %%
import anndata as ad
adata_dict = {}
for model in model_list:
    adata_dict[model] = []
for batch in batch_list:
    for model, model_name in zip(model_list, model_name_list):
        adata_path = f'{base_dir}/{data_dir}/{batch}/{model}/{model_name}.h5ad'
        vkey = f'{model_name}_velocity'
        adata = sc.read_h5ad(adata_path)
        adata_velo = ad.AnnData(X=adata.layers[vkey])
        adata_velo.obs_names = adata.obs_names
        adata_velo.var_names = adata.var_names
        adata_dict[model].append(adata_velo)
adata_concat_dict = {}
for model in model_list:
    adata_concat = ad.concat(adata_dict[model])
    adata_concat_dict[model] = adata_concat
adata_concat_dict
# Out:
# {'scvelo': AnnData object with n_obs × n_vars = 4000 × 535,
#  'unitvelo': AnnData object with n_obs × n_vars = 4000 × 535,
#  'velovae': AnnData object with n_obs × n_vars = 4000 × 535,
#  'deepvelo_cui': AnnData object with n_obs × n_vars = 4000 × 535,
#  'latentvelo': AnnData object with n_obs × n_vars = 4000 × 535,
#  'velovi': AnnData object with n_obs × n_vars = 4000 × 190,
#  'stt': AnnData object with n_obs × n_vars = 4000 × 535,
#  'velovgi': AnnData object with n_obs × n_vars = 4000 × 535}

# %%
data_ref_dir = 'dyngen/batch-dataset_modified'
model_ref_list = ['scvelo', 'unitvelo', 'velovae', 'deepvelo_cui', 'latentvelo', 'velovi', 'stt', 'velovgi']
data_ref_dict = {}
for model, model_ref_dir, model_name in zip(model_list, model_ref_list, model_name_list):
    adata_path = f'{base_dir}/{data_ref_dir}/{model_ref_dir}/{model_name}.h5ad'
    adata = sc.read_h5ad(adata_path)
    adata_batch = adata_concat_dict[model]
    common_genes = list(set(adata.var_names) & set(adata_batch.var_names))
    adata_batch_aligned = adata_batch[:, common_genes].copy()
    adata_aligned = adata[adata_batch_aligned.obs_names, adata_batch_aligned.var_names].copy()
    adata_aligned.layers['batch_velo'] = adata_batch_aligned.X
    data_ref_dict[model] = adata_aligned
data_ref_dict
# Out:
# {'scvelo': AnnData object with n_obs × n_vars = 4000 × 535
#      obs: 'step_ix', 'simulation_i', 'sim_time', 'model', 'progress', 'initial_size_unspliced', 'initial_size_spliced', 'initial_size', 'n_counts', 'velocity_self_transition', 'root_cells', 'end_points', 'velocity_pseudotime', 'latent_time', 'pred_t'
#      var: 'module_id', 'basal', 'burn', 'independence', 'color', 'is_tf', 'is_hk', 'transcription_rate', 'splicing_rate', 'translation_rate', 'mrna_halflife', 'protein_halflife', 'mrna_decay_rate', 'protein_decay_rate', 'max_premrna', 'max_mrna', 'max_protein', 'mol_premrna', 'mol_mrna', 'mol_protein', 'fit_r2', 'fit_alpha', 'fit_beta', 'fit_gamma', 'fit_t_', 'fit_scaling', 'fit_std_u', 'fit_std_s', 'fit_likelihood', 'fit_u0', 'fit_s0', 'fit_pval_steady', 'fit_steady_u', 'fit_steady_s', 'fit_variance', 'fit_alignment_scaling', 'velocity_genes'
#      uns: 'log1p', 'model_colors', 'neighbors', 'pca', 'progress_colors', 'recover_dynamics', 'traj_dimred_segments', 'traj_milestone_network', 'traj_progressions', 'velocity_graph', 'velocity_graph_neg', 'velocity_params'
#      obsm: 'X_pca', 'X_umap', 'dimred'
#      varm: 'PCs', 'loss'
#      layers: 'Ms', 'Mu', 'counts_protein', 'counts_spliced', 'counts_unspliced', 'fit_t', 'fit_tau', 'fit_tau_', 'logcounts', 'rna_velocity', 'scvelo_dynamical_velocity', 'spliced', 'unspliced', 'velocity', 'velocity_u', 'batch_velo'
#      obsp: 'connectivities', 'distances',
#  'unitvelo': AnnData object with n_obs × n_vars = 4000 × 535
#      obs: 'step_ix', 'simulation_i', 'sim_time', 'model', 'progress', 'initial_size_unspliced', 'initial_size_spliced', 'initial_size', 'n_counts', 'velocity_self_transition', 'root_cells', 'end_points', 'velocity_pseudotime', 'latent_time', 'pred_t'
#      var: 'module_id', 'basal', 'burn', 'independence', 'color', 'is_tf', 'is_hk', 'transcription_rate', 'splicing_rate', 'translation_rate', 'mrna_halflife', 'protein_halflife', 'mrna_decay_rate', 'protein_decay_rate', 'max_premrna', 'max_mrna', 'max_protein', 'mol_premrna', 'mol_mrna', 'mol_protein', 'highly_variable', 'velocity_gamma', 'velocity_r2', 'scaling', 'velocity_genes', 'fit_vars', 'fit_varu', 'fit_gamma', 'fit_beta', 'fit_offset', 'fit_a', 'fit_t', 'fit_h', 'fit_intercept', 'fit_loss', 'fit_llf', 'fit_sr2', 'fit_ur2'
#      uns: 'base_function', 'basis', 'datapath', 'label', 'log1p', 'loss', 'model_colors', 'neighbors', 'par_names', 'pca', 'progress_colors', 'temp', 'traj_dimred_segments', 'traj_milestone_network', 'traj_progressions', 'velocity_graph', 'velocity_graph_neg', 'velocity_params'
#      obsm: 'X_pca', 'X_umap', 'dimred', 'velocity_umap'
#      varm: 'PCs'
#      layers: 'Ms', 'Mu', 'Mu_scale', 'counts_protein', 'counts_spliced', 'counts_unspliced', 'fit_t', 'logcounts', 'rna_velocity', 'spliced', 'unitvelo_velocity', 'unspliced', 'velocity', 'batch_velo'
#      obsp: 'connectivities', 'distances',
#  'velovae': AnnData object with n_obs × n_vars = 4000 × 535
#      obs: 'step_ix', 'simulation_i', 'sim_time', 'model', 'progress', 'initial_size_unspliced', 'initial_size_spliced', 'initial_size', 'n_counts', 'vae_time', 'vae_std_t', 'vae_t0', 'pred_t'
#      var: 'module_id', 'basal', 'burn', 'independence', 'color', 'is_tf', 'is_hk', 'transcription_rate', 'splicing_rate', 'translation_rate', 'mrna_halflife', 'protein_halflife', 'mrna_decay_rate', 'protein_decay_rate', 'max_premrna', 'max_mrna', 'max_protein', 'mol_premrna', 'mol_mrna', 'mol_protein', 'init_mode', 'w_init', 'vae_alpha', 'vae_beta', 'vae_gamma', 'vae_ton', 'vae_scaling', 'vae_sigma_u', 'vae_sigma_s'
#      uns: 'log1p', 'model_colors', 'neighbors', 'pca', 'progress_colors', 'traj_dimred_segments', 'traj_milestone_network', 'traj_progressions', 'vae_run_time', 'vae_test_idx', 'vae_train_idx'
#      obsm: 'X_pca', 'X_umap', 'dimred', 'vae_std_z', 'vae_z'
#      varm: 'PCs', 'vae_mode'
#      layers: 'Ms', 'Mu', 'counts_protein', 'counts_spliced', 'counts_unspliced', 'logcounts', 'rna_velocity', 'spliced', 'unspliced', 'vae_rho', 'vae_s0', 'vae_shat', 'vae_u0', 'vae_uhat', 'vae_velocity', 'vae_velocity_u', 'velovae_velocity', 'batch_velo'
#      obsp: 'connectivities', 'distances',
#  'deepvelo_cui': AnnData object with n_obs × n_vars = 4000 × 535
#      obs: 'step_ix', 'simulation_i', 'sim_time', 'model', 'progress', 'initial_size_unspliced', 'initial_size_spliced', 'initial_size', 'n_counts', 'velocity_self_transition', 'root_cells', 'end_points', 'velocity_pseudotime', 'latent_time', 'pred_t'
#      var: 'module_id', 'basal', 'burn', 'independence', 'color', 'is_tf', 'is_hk', 'transcription_rate', 'splicing_rate', 'translation_rate', 'mrna_halflife', 'protein_halflife', 'mrna_decay_rate', 'protein_decay_rate', 'max_premrna', 'max_mrna', 'max_protein', 'mol_premrna', 'mol_mrna', 'mol_protein', 'velocity_gamma', 'velocity_r2', 'velocity_genes'
#      uns: 'model_colors', 'neighbors', 'pca', 'progress_colors', 'traj_dimred_segments', 'traj_milestone_network', 'traj_progressions', 'velocity_graph', 'velocity_graph_neg', 'velocity_params'
#      obsm: 'X_pca', 'X_umap', 'dimred'
#      varm: 'PCs'
#      layers: 'Ms', 'Mu', 'cell_specific_alpha', 'cell_specific_beta', 'cell_specific_gamma', 'counts_protein', 'counts_spliced', 'counts_unspliced', 'deepvelo_cui_velocity', 'logcounts', 'rna_velocity', 'spliced', 'unspliced', 'variance_velocity', 'velocity', 'velocity_unspliced', 'batch_velo'
#      obsp: 'connectivities', 'distances',
#  'latentvelo': AnnData object with n_obs × n_vars = 4000 × 535
#      obs: 'step_ix', 'simulation_i', 'sim_time', 'model', 'progress', 'spliced_size_factor', 'unspliced_size_factor', 'batch_id', 'celltype_id', 'root', 'terminal', 'latent_time', 'pred_t'
#      var: 'module_id', 'basal', 'burn', 'independence', 'color', 'is_tf', 'is_hk', 'transcription_rate', 'splicing_rate', 'translation_rate', 'mrna_halflife', 'protein_halflife', 'mrna_decay_rate', 'protein_decay_rate', 'max_premrna', 'max_mrna', 'max_protein', 'mol_premrna', 'mol_mrna', 'mol_protein', 'velocity_genes', 'R2', 'R2_traj', 'R2_test', 'R2_traj_test'
#      uns: 'index_test', 'model_colors', 'neighbors', 'pca', 'progress_colors', 'scale_spliced', 'scale_unspliced', 'traj_dimred_segments', 'traj_milestone_network', 'traj_progressions'
#      obsm: 'X_latent', 'X_pca', 'X_umap', 'batch_onehot', 'dimred', 'latent_velocity'
#      varm: 'PCs'
#      layers: 'Ms', 'Mu', 'counts_protein', 'counts_spliced', 'counts_unspliced', 'latentvelo_velocity', 'logcounts', 'mask_spliced', 'mask_unspliced', 'rna_velocity', 'spliced', 'spliced_counts', 'spliced_raw', 'unspliced', 'unspliced_counts', 'unspliced_raw', 'velo', 'velo_s', 'velo_u', 'batch_velo'
#      obsp: 'adj', 'connectivities', 'distances',
#  'velovi': AnnData object with n_obs × n_vars = 4000 × 187
#      obs: 'step_ix', 'simulation_i', 'sim_time', 'model', 'progress', 'initial_size_unspliced', 'initial_size_spliced', 'initial_size', 'n_counts'
#      var: 'module_id', 'basal', 'burn', 'independence', 'color', 'is_tf', 'is_hk', 'transcription_rate', 'splicing_rate', 'translation_rate', 'mrna_halflife', 'protein_halflife', 'mrna_decay_rate', 'protein_decay_rate', 'max_premrna', 'max_mrna', 'max_protein', 'mol_premrna', 'mol_mrna', 'mol_protein', 'velocity_gamma', 'velocity_qreg_ratio', 'velocity_r2', 'velocity_genes', 'fit_alpha', 'fit_beta', 'fit_gamma', 'fit_t_', 'fit_scaling'
#      uns: '_scvi_manager_uuid', '_scvi_uuid', 'log1p', 'model_colors', 'neighbors', 'pca', 'progress_colors', 'traj_dimred_segments', 'traj_milestone_network', 'traj_progressions', 'velocity_params'
#      obsm: 'X_pca', 'X_umap', 'dimred'
#      varm: 'PCs'
#      layers: 'Ms', 'Mu', 'counts_protein', 'counts_spliced', 'counts_unspliced', 'fit_t', 'latent_time_velovi', 'logcounts', 'rna_velocity', 'spliced', 'unspliced', 'velocity', 'velovi_velocity', 'batch_velo'
#      obsp: 'connectivities', 'distances',
#  'stt': AnnData object with n_obs × n_vars = 4000 × 535
#      obs: 'step_ix', 'simulation_i', 'sim_time', 'model', 'progress', 'initial_size_unspliced', 'initial_size_spliced', 'initial_size', 'n_counts', 'attractor', 'entropy', 'speed'
#      var: 'module_id', 'basal', 'burn', 'independence', 'color', 'is_tf', 'is_hk', 'transcription_rate', 'splicing_rate', 'translation_rate', 'mrna_halflife', 'protein_halflife', 'mrna_decay_rate', 'protein_decay_rate', 'max_premrna', 'max_mrna', 'max_protein', 'mol_premrna', 'mol_mrna', 'mol_protein', 'r2_train', 'r2_test'
#      uns: 'da_out', 'gene_subset', 'log1p', 'model_colors', 'neighbors', 'par', 'pca', 'progress_colors', 'r2_keep_test', 'r2_keep_train', 'traj_dimred_segments', 'traj_milestone_network', 'traj_progressions'
#      obsm: 'X_pca', 'X_umap', 'dimred', 'rho', 'tensor_v', 'tensor_v_aver'
#      varm: 'PCs'
#      layers: 'Ms', 'Mu', 'counts_protein', 'counts_spliced', 'counts_unspliced', 'logcounts', 'rna_velocity', 'spliced', 'stt_velocity', 'unspliced', 'velo', 'batch_velo'
#      obsp: 'connectivities', 'distances',
#  'velovgi': AnnData object with n_obs × n_vars = 4000 × 535
#      obs: 'step_ix', 'simulation_i', 'sim_time', 'model', 'progress', 'initial_size_unspliced', 'initial_size_spliced', 'initial_size', 'n_counts'
#      var: 'module_id', 'basal', 'burn', 'independence', 'color', 'is_tf', 'is_hk', 'transcription_rate', 'splicing_rate', 'translation_rate', 'mrna_halflife', 'protein_halflife', 'mrna_decay_rate', 'protein_decay_rate', 'max_premrna', 'max_mrna', 'max_protein', 'mol_premrna', 'mol_mrna', 'mol_protein', 'fit_alpha', 'fit_beta', 'fit_gamma', 'fit_t_', 'fit_scaling'
#      uns: '_scvi_manager_uuid', '_scvi_uuid', 'model_colors', 'neighbors', 'pca', 'progress_colors', 'traj_dimred_segments', 'traj_milestone_network', 'traj_progressions'
#      obsm: 'X_pca', 'X_umap', 'dimred'
#      varm: 'PCs'
#      layers: 'Ms', 'Mu', 'counts_protein', 'counts_spliced', 'counts_unspliced', 'fit_t', 'latent_time_velovgi', 'logcounts', 'rna_velocity', 'spliced', 'unspliced', 'velocity', 'velocity_u', 'velovgi_velocity', 'batch_velo'
#      obsp: 'connectivities', 'distances'}

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
n_rows = 2
n_cols = 4
fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 5, n_rows * 5))

for i, (model, adata) in enumerate(data_ref_dict.items()):
    vkey = f'{model_name_list[i]}_velocity'
    non_nan_cols = ~np.isnan(adata.layers['batch_velo']).any(axis=0) & ~np.isnan(adata.layers[vkey]).any(axis=0)
    adata = adata[:, non_nan_cols].copy()
    print(model, adata.n_vars)
    adata.obs['batch_sim'] = cosine_similarity(adata.layers['batch_velo'], adata.layers[vkey]).diagonal()
    scv.pl.scatter(adata, basis=basis, color='batch_sim', title=model, color_map='plasma', vmin=-1, vmax=1, ax=axes[i // n_cols, i % n_cols], show=False, colorbar=False)
plt.tight_layout()
plt.savefig(f'{save_dir}/batch_velocity_correlation.svg', bbox_inches='tight')
plt.show()
# Out:
# scvelo 191
# unitvelo 522
# velovae 535
# deepvelo_cui 535
# latentvelo 535
# velovi 187
# stt 535
# velovgi 535
